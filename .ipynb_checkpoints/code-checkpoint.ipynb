# %% [markdown]
# **Dataset**: JPMorgan Chase & Co. stock prices starting 01-01-2001 (sourced from [Yahoo! Finance](http://finance.yahoo.com/quote/JPM/history?p=JPM)).
#
# **Task**: Anomaly Detection using LSTM-based Autoencoder.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## load dataset

data = pd.read_csv('JPM.csv', usecols=['Date','Open'])
data.head()
# Out:
#          Date       Open
# 0  2000-01-03  49.833332
# 1  2000-01-04  47.083332
# 2  2000-01-05  46.833332
# 3  2000-01-06  46.750000
# 4  2000-01-07  48.416668

# %%
## null value check

data.isnull().sum()
# Out:
# Date    0
# Open    0
# dtype: int64

# %%
## convert 'Date'--> datetime and set as index

data['Date'] = data['Date'].apply(lambda str_date: pd.to_datetime(str_date))

data.set_index('Date', inplace=True)

data.head()
# Out:
#                  Open
# Date
# 2000-01-03  49.833332
# 2000-01-04  47.083332
# 2000-01-05  46.833332
# 2000-01-06  46.750000
# 2000-01-07  48.416668

# %%
## visualizing data

fig = plt.figure(figsize=(16,6))

plt.plot(data['Open'])
plt.xlabel('Date')
plt.ylabel('Stock Price (in USD)')

plt.show()

# %% [raw]
# Step 1: Data processing

# %%
## train test split

train = data[data.index < pd.to_datetime('01-01-2018')]
test = data[data.index >= pd.to_datetime('01-01-2018')]

# %%
train.shape
# Out:
# (4528, 1)

# %%
test.shape
# Out:
# (1409, 1)

# %%
## data normalization

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))

scaler.fit(train)

train = scaler.transform(train)
test = scaler.transform(test)

# %%
train[:10]
# Out:
# array([[0.37125211],
#        [0.34162806],
#        [0.33893497],
#        [0.33803728],
#        [0.35599126],
#        [0.35688895],
#        [0.3371396 ],
#        [0.33489532],
#        [0.34521888],
#        [0.3654171 ]])

# %%
test[:10]
# Out:
# array([[0.99385974],
#        [0.99633743],
#        [1.00172362],
#        [1.01141878],
#        [0.99946143],
#        [1.00560168],
#        [1.01368097],
#        [1.02660779],
#        [1.03716476],
#        [1.03565663]])

# %%
## convert data into proper format

time_steps = 60

def convert(data, time_steps):
    
    X = list()
    
    for i in range(time_steps, len(data)):
        
        obs = data[i-time_steps:i,0].reshape(time_steps) ## observations
        
        X.append(obs)
        
    X = np.array(X)
    
    X = np.reshape(X, (X.shape[0],X.shape[1],1))
    
    return X

# %%
X_train = convert(data=train, time_steps=time_steps)
X_test = convert(data=test, time_steps=time_steps)

# %%
X_train.shape
# Out:
# (4468, 60, 1)

# %%
X_test.shape
# Out:
# (1349, 60, 1)

# %% [raw]
# Step 2: Model building

# %%
## imports

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, RepeatVector, TimeDistributed
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
model = Sequential() ## initialization

model.add(LSTM(units=3*X_train.shape[1], activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(rate=0.5)) ## 30% perceptrons turned off at every pass
## output_shape --> (batch_size, 3*X_train.shape[1])
model.add(RepeatVector(n=X_train.shape[1]))
## output_shape --> (batch_size, 3*X_train.shape[1], X_train.shape[1])
model.add(LSTM(units=3*X_train.shape[1], activation='tanh', return_sequences=True))
model.add(Dropout(rate=0.5)) ## 30% perceptrons turned off at every pass
## output_shape --> (batch_size, 3*X_train.shape[1], X_train.shape[1])
model.add(TimeDistributed(Dense(units=X_train.shape[2])))
## output_shape --> (batch_size, 3*X_train.shape[1], 1) --> SAME AS INPUT (AUTOENCODER CONCEPT)

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 180)               131040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 180)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 60, 180)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60, 180)           259920
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 180)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 60, 1)             181
# =================================================================
# Total params: 391,141
# Trainable params: 391,141
# Non-trainable params: 0
# _________________________________________________________________

# %%
## training

history = model.fit(x=X_train,
                   y=X_train,
                   batch_size=64,
                   epochs=100,
                   validation_split=0.1,
                   shuffle=False)

## notice how X_train is both the input and the target
# Out:
# WARNING:tensorflow:From C:\Users\abhin\anaconda3\envs\nlp_course\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4021 samples, validate on 447 samples
# Epoch 1/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0108 - val_loss: 0.0143
# Epoch 2/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0060 - val_loss: 0.0135
# Epoch 3/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0058 - val_loss: 0.0107
# Epoch 4/100
# 4021/4021 [==============================] - 16s 4ms/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 5/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0072 - val_loss: 0.0083
# Epoch 6/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 7/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 8/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0076 - val_loss: 0.0103
# Epoch 9/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0075 - val_loss: 0.0094
# Epoch 10/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0065 - val_loss: 0.0079
# Epoch 11/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0057 - val_loss: 0.0086
# Epoch 12/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 13/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 14/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 15/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 16/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0034
# Epoch 17/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 18/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0031
# Epoch 19/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 20/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 21/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 22/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 23/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 24/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 25/100
# 4021/4021 [==============================] - 16s 4ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 26/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0023 - val_loss: 0.0032
# Epoch 27/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0032
# Epoch 28/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 29/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 30/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0034
# Epoch 31/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 32/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 33/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 34/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0039
# Epoch 35/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 36/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0041
# Epoch 37/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 38/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 39/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 40/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 41/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 42/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 43/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0044
# Epoch 44/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0044
# Epoch 45/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0048
# Epoch 46/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0049
# Epoch 47/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0053
# Epoch 48/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0024 - val_loss: 0.0053
# Epoch 49/100
# 4021/4021 [==============================] - 16s 4ms/step - loss: 0.0024 - val_loss: 0.0058
# Epoch 50/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0024 - val_loss: 0.0060
# Epoch 51/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0024 - val_loss: 0.0062
# Epoch 52/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0062
# Epoch 53/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0026 - val_loss: 0.0067
# Epoch 54/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0026 - val_loss: 0.0068
# Epoch 55/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0027 - val_loss: 0.0069
# Epoch 56/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0027 - val_loss: 0.0071
# Epoch 57/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0029 - val_loss: 0.0059
# Epoch 58/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0024 - val_loss: 0.0065
# Epoch 59/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0029 - val_loss: 0.0050
# Epoch 60/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0050
# Epoch 61/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0040
# Epoch 62/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 63/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 64/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 65/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0019 - val_loss: 0.0056
# Epoch 66/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0067
# Epoch 67/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0019 - val_loss: 0.0070
# Epoch 68/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0080
# Epoch 69/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0079
# Epoch 70/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0079
# Epoch 71/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0024 - val_loss: 0.0075
# Epoch 72/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0025 - val_loss: 0.0070
# Epoch 73/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0076
# Epoch 74/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0078
# Epoch 75/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0071
# Epoch 76/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0071
# Epoch 77/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0023 - val_loss: 0.0065
# Epoch 78/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0066
# Epoch 79/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0059
# Epoch 80/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 81/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 82/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0016 - val_loss: 0.0069
# Epoch 83/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0016 - val_loss: 0.0070
# Epoch 84/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0064
# Epoch 85/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0059
# Epoch 86/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 87/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0019 - val_loss: 0.0053
# Epoch 88/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0055
# Epoch 89/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 90/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 91/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 92/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 93/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0034
# Epoch 94/100
# 4021/4021 [==============================] - 15s 4ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 95/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 96/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0034
# Epoch 97/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 98/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 99/100
# 4021/4021 [==============================] - 14s 3ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 100/100
# 4021/4021 [==============================] - 14s 4ms/step - loss: 0.0017 - val_loss: 0.0032

# %%
## plot loss over epochs

fig = plt.figure(figsize=(16,6))

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()

plt.show()

# %% [raw]
# Step 3: Determining threshold value

# %%
## mean absolute error loss across samples

train_mae_loss = np.mean(np.abs(model.predict(X_train)-X_train), axis=1)

## histogram of mean absolute error

fig = plt.figure(figsize=(16,6))

plt.hist(train_mae_loss, bins=50)
plt.title('Train')
plt.xlabel('MAE Loss')
plt.ylabel('Samples')

plt.show()

# %%
threshold = np.max(train_mae_loss) ## this is the max error that our model produced while reconstructing an input
threshold
# Out:
# 0.12904502683835464

# %%
## test mae loss
test_mae_loss = np.mean(np.abs(model.predict(X_test)-X_test), axis=1)

## histogram of mean absolute error

fig = plt.figure(figsize=(16,6))

plt.hist(test_mae_loss, bins=50)
plt.title('Test')
plt.xlabel('MAE Loss')
plt.ylabel('Samples')

plt.show()

# %% [raw]
# Step 4: Anomaly detection

# %%
anomalies = test_mae_loss > threshold

anomalous_data_indices = [] ## indices of test observations that represent anomalies

for data_idx in range(time_steps - 1, len(test) - time_steps + 1):
    
    if np.all(anomalies[data_idx - time_steps + 1 : data_idx]):
        
        anomalous_data_indices.append(data_idx)

# %% [markdown]
# Refer [this]("https://keras.io/examples/timeseries/timeseries_anomaly_detection/") to understand above code.

# %%
## reconstruction

test = scaler.inverse_transform(test)

reconstruct = pd.DataFrame(data=test, index=data.index[len(data)-len(test):], columns=['Open'])

test_anomalies = reconstruct.iloc[anomalous_data_indices]

fig, ax = plt.subplots(figsize=(16,6))

reconstruct.plot(legend=False, ax=ax)

ax.scatter(x=test_anomalies.index, y=test_anomalies['Open'], color="r")

plt.show()

# %% [markdown]
# **Important**: the red dot represent anomalies in the test set.

# %%
## save model

from keras.models import save_model
save_model(model, 'LSTM_Autoencoder_timesteps60_epochs100_batchsize64.h5')
